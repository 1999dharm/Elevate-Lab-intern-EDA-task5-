# %%
# importing library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset
data = pd.read_csv('titanic_train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# data.head() return top 5 record from the dataset
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# data.tail() return last 5 record from the dataset
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Using .info() to get a summary of the DataFrame (like data types and missing values)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Using .describe() to get statistical summary of numerical columns
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Shows the frequency of each unique value in a sex column.
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# data.isnull() to check null values in columns
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Filling missing values in 'Age' column with the mean() value
data['Age'].mean()

data['Age'].fillna(data['Age'].mean(),inplace=True)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_26612\439807267.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(data['Age'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Dropping the 'Cabin' column due to a high percentage of missing values (approximately 77%).
# The 'Cabin' feature was considered less useful for the analysis/model because of the large number of nulls.
# Removing it simplifies the dataset without losing significant information.
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
# Dropping the 'Cabin' column due to a high percentage of missing values (approximately 77%).
# The 'Cabin' feature was considered less useful for the analysis/model because of the large number of nulls.
# Removing it simplifies the dataset without losing significant information.
data.drop('Cabin',axis=1,inplace=True)

# %%
# drop the missing value from emnarked column 
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# Check the data types of each column
print(data.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
# Select only numeric column
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# %%
# Select only numeric columns
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Plot the heatmap
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Here are short observations for each relationship in the correlation heatmap:
#
# PassengerId: No significant correlation with other variables.
#
# Survived: Positively related to Fare, negatively related to Pclass.
#
# Pclass: Negatively related to Survived and Fare.
#
# Age: Weakly related to other variables.
#
# SibSp: Moderately related to Parch.
#
# Parch: Moderately related to SibSp.
#
# Fare: Positively related to Survived, negatively related to Pclass.

# %%
# Pairplot to show relationships between numerical features
sns.pairplot(data[['Age','Fare','SibSp']])
plt.show()

# %%
# Scatter plot between Age and Fare to check correlation
sns.scatterplot(x='Age', y='Fare', data=data)
plt.title('Scatter Plot of Age vs Fare')
plt.show()

# %% [markdown]
# Weak Correlation: Age and Fare have minimal to no correlation.
#
# Fare Concentration: Most fares are low.
#
# Age Spread: Low fares occur across all ages.
#
# High Fares: High fares are infrequent.
#
# Age at High Fares: High fares are seen across different age groups.

# %%
# Count plot for Sex distribution
sns.countplot(data=data, x='Sex',hue='Sex')
plt.title('Count of Males and Females')
plt.show()

# %% [markdown]
# Male Count: Significantly higher than female count.
#
# Female Count: Substantially lower than male count.

# %%
# Distribution plot for Age
sns.histplot(data['Age'], kde=True)
plt.title('Age Distribution of Passengers')
plt.show()

# %% [markdown]
# Peak Age Group: Most passengers are in their 20s and 30s.
#
# Right Skew: The distribution is skewed to the right, indicating more younger passengers.
#
# Fewer Older Passengers: The number of passengers decreases with age.
#
# Young Children: There is a small peak for very young children.

# %%
# List of custom colors for each Pclass (assuming there are 3 Pclass values)
custom_colors = ['#FF6347', '#4682B4', '#32CD32']  # Red, Blue, Green

# Bar plot for survival rate by Pclass with custom colors
sns.barplot(x='Pclass', y='Survived', data=data, palette=custom_colors)

plt.title('Survival Rate by Pclass')
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_26612\1286154388.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Pclass', y='Survived', data=data, palette=custom_colors)

# %% [markdown]
# Class 1 Highest Survival: Passengers in the first class had the highest survival rate.
#
# Class 3 Lowest Survival: Passengers in the third class had the lowest survival rate.
#
# Decreasing Survival with Class: Survival rate decreases as passenger class goes from 1st to 3rd.
#
# Class disparity: There is a clear disparity in survival rates across different passenger classes.

# %%
# Count plot for Embarked (boarding ports)
custom_colors = ['pink', '#4682B4', 'yellow']  # Red, Blue, Green
sns.countplot(data=data, x='Embarked', palette=custom_colors)
plt.title('Number of Passengers by Embarked Port')
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_26612\432739251.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Embarked', palette=custom_colors)

# %%
# FacetGrid to visualize Survived vs Sex
sns.catplot(x='Sex', hue='Survived', kind='count', data=data)
plt.title('Survival Count by Gender')
plt.show()
